# %%
chinese = 78
english = 50
math = 73

total = chinese + english + math
print("total=", total)
# Out:
# total= 201

# %%
apple = int(input("請輸入蘋果的數量:"))
orange = int(input("請輸入橘子的數量:"))

print("蘋果=" + str(apple) + "個,橘子=" + str(orange) + "個")
# Out:
# 蘋果=15個,橘子=96個

# %%
print(f"蘋果={apple}個,橘子={orange}個")
# Out:
# 蘋果=15個,橘子=96個

# %%
# input()
apple = int(input("請輸入蘋果的數量:"))
orange = str(input("請輸入橘子的數量:"))
type(apple)
type(orange)
# Out:
# str
