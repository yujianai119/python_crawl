# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler

nest_asyncio.apply()

async def main():
    #建立一個AsyncWebCrawler的實體
    async with AsyncWebCrawler() as crawler:
        #Run the crawler on a URL
        result = await crawler.arun(url='https://www.bnext.com.tw/')

        #列印取出的結果
        print(result.markdown)

#py檔執行
asyncio.run(main())
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-2' coro=<Connection.run() done, defined at d:\Github\python_crawl\.venv\Lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "C:\Users\cjyeh\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "d:\Github\python_crawl\.venv\Lib\site-packages\playwright\_impl\_connection.py", line 312, in run
#     await self._transport.connect()
#   File "d:\Github\python_crawl\.venv\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "d:\Github\python_crawl\.venv\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cjyeh\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\subprocess.py", line 223, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cjyeh\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\base_events.py", line 1708, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cjyeh\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\base_events.py", line 503, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[1], line 17
#      14         print(result.markdown)
#      16 #py檔執行
# ---> 17 asyncio.run(main())
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# Cell In[1], line 9, in main()
#       7 async def main():
#       8     #建立一個AsyncWebCrawler的實體
# ----> 9     async with AsyncWebCrawler() as crawler:
#      10         #Run the crawler on a URL
#      11         result = await crawler.arun(url='https://www.bnext.com.tw/')
#      13         #列印取出的結果
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\crawl4ai\async_webcrawler.py:194, in AsyncWebCrawler.__aenter__(self)
#     193 async def __aenter__(self):
# --> 194     return await self.start()
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\crawl4ai\async_webcrawler.py:177, in AsyncWebCrawler.start(self)
#     170 async def start(self):
#     171     """
#     172     Start the crawler explicitly without using context manager.
#     173     This is equivalent to using 'async with' but gives more control over the lifecycle.
#     174     Returns:
#     175         AsyncWebCrawler: The initialized crawler instance
#     176     """
# --> 177     await self.crawler_strategy.__aenter__()
#     178     self.logger.info(f"Crawl4AI {crawl4ai_version}", tag="INIT")
#     179     self.ready = True
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\crawl4ai\async_crawler_strategy.py:119, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     118 async def __aenter__(self):
# --> 119     await self.start()
#     120     return self
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\crawl4ai\async_crawler_strategy.py:129, in AsyncPlaywrightCrawlerStrategy.start(self)
#     125 async def start(self):
#     126     """
#     127     Start the browser and initialize the browser manager.
#     128     """
# --> 129     await self.browser_manager.start()
#     130     await self.execute_hook(
#     131         "on_browser_created",
#     132         self.browser_manager.browser,
#     133         context=self.browser_manager.default_context,
#     134     )
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\crawl4ai\browser_manager.py:659, in BrowserManager.start(self)
#     656     from playwright.async_api import async_playwright
#     658 # Initialize playwright
# --> 659 self.playwright = await async_playwright().start()
#     661 if self.config.cdp_url or self.config.use_managed_browser:
#     662     self.config.use_managed_browser = True
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:51, in PlaywrightContextManager.start(self)
#      50 async def start(self) -> AsyncPlaywright:
# ---> 51     return await self.__aenter__()
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File d:\Github\python_crawl\.venv\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\subprocess.py:223, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     220 loop = events.get_running_loop()
#     221 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     222                                                     loop=loop)
# --> 223 transport, protocol = await loop.subprocess_exec(
#     224     protocol_factory,
#     225     program, *args,
#     226     stdin=stdin, stdout=stdout,
#     227     stderr=stderr, **kwds)
#     228 return Process(transport, protocol, loop)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\base_events.py:1708, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1706     debug_log = f'execute program {program!r}'
#    1707     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1708 transport = await self._make_subprocess_transport(
#    1709     protocol, popen_args, False, stdin, stdout, stderr,
#    1710     bufsize, **kwargs)
#    1711 if self._debug and debug_log is not None:
#    1712     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.14-windows-x86_64-none\Lib\asyncio\base_events.py:503, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     499 async def _make_subprocess_transport(self, protocol, args, shell,
#     500                                      stdin, stdout, stderr, bufsize,
#     501                                      extra=None, **kwargs):
#     502     """Create subprocess transport."""
# --> 503     raise NotImplementedError
#
# NotImplementedError:
